# %%
import sys, platform
print(sys.executable)
print(sys.version)
print(platform.platform())
assert ".venv" in sys.executable.lower()
print("ready")
# Out:
# d:\Roberto Byas\Desktop\8239\INF8239_U01\.venv\Scripts\python.exe
# 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
# Windows-11-10.0.26200-SP0
# ready
